# %%
from gasm import grafiquita
from gasm import hello_kitty
# from IPython.core.display import display, HTML

# %%
grafiquita()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# <div>
# <script type="text/javascript">
#     (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
#               (function(root) {
#                 function embed_document(root) {
#
#                 var docs_json = '{"b76eb1a4-cf9e-42d2-b9c2-041f42fc0c8a":{"roots":{"references":[{"attributes":{},"id":"1043","type":"BasicTickFormatter"},{"attributes":{"end":2025,"start":1970},"id":"1009","type":"Range1d"},{"attributes":{"end":3,"start":-0.5},"id":"1007","type":"Range1d"},{"attributes":{},"id":"1011","type":"LinearScale"},{"attributes":{"source":{"id":"1002"}},"id":"1028","type":"CDSView"},{"attributes":{"below":[{"id":"1015"}],"border_fill_color":"white","center":[{"id":"1018"},{"id":"1022"}],"left":[{"id":"1019"}],"min_border_bottom":50,"min_border_left":200,"min_border_right":100,"min_border_top":50,"plot_height":800,"plot_width":480,"renderers":[{"id":"1027"},{"id":"1032"}],"title":{"id":"1005"},"toolbar":{"id":"1023"},"x_range":{"id":"1007"},"x_scale":{"id":"1011"},"y_range":{"id":"1009"},"y_scale":{"id":"1013"}},"id":"1004","subtype":"Figure","type":"Plot"},{"attributes":{"ticks":[]},"id":"1038","type":"FixedTicker"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"red"},"line_alpha":{"value":0.8},"line_color":{"value":"red"},"size":{"units":"screen","value":10},"x":{"value":2},"y":{"field":"year"}},"id":"1030","type":"Circle"},{"attributes":{"axis_label":"Year","formatter":{"id":"1043"},"minor_tick_line_color":null,"ticker":{"id":"1020"}},"id":"1019","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"value":0},"y":{"field":"year"}},"id":"1026","type":"Circle"},{"attributes":{},"id":"1044","type":"Selection"},{"attributes":{"axis":{"id":"1015"},"grid_line_color":null,"ticker":null},"id":"1018","type":"Grid"},{"attributes":{},"id":"1045","type":"UnionRenderers"},{"attributes":{},"id":"1020","type":"BasicTicker"},{"attributes":{"data_source":{"id":"1002"},"glyph":{"id":"1025"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1026"},"selection_glyph":null,"view":{"id":"1028"}},"id":"1027","type":"GlyphRenderer"},{"attributes":{"axis":{"id":"1019"},"dimension":1,"grid_line_color":null,"ticker":null},"id":"1022","type":"Grid"},{"attributes":{"source":{"id":"1003"}},"id":"1033","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"red"},"line_alpha":{"value":0.1},"line_color":{"value":"red"},"size":{"units":"screen","value":10},"x":{"value":2},"y":{"field":"year"}},"id":"1031","type":"Circle"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1034"},{"id":"1035"}]},"id":"1023","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.8},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"value":0},"y":{"field":"year"}},"id":"1025","type":"Circle"},{"attributes":{"axis_label":"Events","formatter":{"id":"1041"},"minor_tick_line_color":null,"ticker":{"id":"1038"}},"id":"1015","type":"LinearAxis"},{"attributes":{"text":"Hello Kitty &amp; Grecia Timeline"},"id":"1005","type":"Title"},{"attributes":{},"id":"1013","type":"LinearScale"},{"attributes":{"data":{"event":["Un Gatite was born","Mi, first kitten","Promotora UBA","Se une a la Twitter y a la UEC","29 a\\u00f1os, Lechuga &amp; Pechuga"],"image":["https://raw.githubusercontent.com/AltamarMx/gasm/main/gasm/img/new_born.jpg","https://raw.githubusercontent.com/AltamarMx/gasm/main/gasm/img/first.jpg","https://raw.githubusercontent.com/AltamarMx/gasm/main/gasm/img/ier.png","https://raw.githubusercontent.com/AltamarMx/gasm/main/gasm/img/python.png","https://raw.githubusercontent.com/AltamarMx/gasm/main/gasm/img/canion_sumidero.png"],"index":[0,1,2,3,4],"year":[1994,2015,2019,2021,2023]},"selected":{"id":"1046"},"selection_policy":{"id":"1047"}},"id":"1003","type":"ColumnDataSource"},{"attributes":{"callback":null,"renderers":[{"id":"1032"}],"tooltips":"\\n        &lt;div&gt;\\n            & ...
#                 var render_items = [{"docid":"b76eb1a4-cf9e-42d2-b9c2-041f42fc0c8a","root_ids":["1004"],"roots":{"1004":"6ae86431-932a-4b96-9d53-8937c2ce86b2"}}];
#                 root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                 }
#                 if (root.Bokeh !== undefined) {
#                   embed_document(root);
#                 } else {
#                   var attempts = 0;
#                   var timer = setInterval(function(root) {
#                     if (root.Bokeh !== undefined) {

# %%
hello_kitty()
# Out:
# Let your heart guide your way
